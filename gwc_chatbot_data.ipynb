# %% [markdown]
# <a href="https://colab.research.google.com/github/s-grzhang/gwc-chatbot/blob/optimization/gwc_chatbot_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTANT: Push to web-interface branch, not main branch.

# %%
#Add more data & replace GWC with Girls Who Code or vice versa on paraphrased data points.
#For mustang extravaganza, add prompts related to parents.
import pandas as pd
from google.colab import drive

# Create a DataFrame with your data
data = {
    'User Input': [
        'When and where does Girls Who Code (GWC) meet?',
        'What day does GWC meet?',
        'What time does GWC meet?',
        'What room does Girls Who Code meet?',
        'When do Girls Who Code meetings end?',
        'How long are Girls Who Code meetings?',
        'Who is Redmond High School Girls Who Code\'s advisor?',
        'What is the purpose of Girls Who Code?',
        'Who can join GWC (Girls Who Code)?',
        'How do I join the club?',
        'Are there any membership fees or costs?',
        'What kind of activities does GWC organize?',
        'Do I need any prior coding experience to join?',
        'How often does the club meet?',
        'What skills will I learn in the club?',
        'Will there be opportunities for internships or scholarships?',
        'Can the club help with college applications?',
        'What requirements are there to run for the board?',
        'How can I contact the club\'s leadership?',
        'What is the history of Girls Who Code?',
        'Do you have any partnerships with other clubs?',
        'Are there any prerequisites to join?',
        'What programming languages will I learn?',
        'Are there any certifications or recognitions offered by the club?',
        'Will there be opportunities to work on real-world projects?',
        'How can I access the meeting materials after I have missed a meeting?',
        'What type of hackathons does the club participate in?',
        'Can I propose new events or workshops for the club?',
        'What are the club’s social media handles?',
        'What are the roles and responsibilities of the board members?',
        'Are there any surveys or feedback forms available?',
        'What changes or improvements are planned for the club?',
        'How is Girls Who Code different from other computer science clubs?',
        'Can boys join GWC?',
        'Why should girls join Girls Who Code?',
        'How many members does Girls Who Code have?',
        'How are board members elected?',
        'What are the grades of the board members?',
        'What kind of equipment will members need?',
        'What platforms will the club use to communicate with its members?',
        'Why should girls go into computer science?',
        'What fields of computer science will Girls Who Code cover?',
        'Is Girls Who Code fun?',
        'What is Girls Who Code?',
        'Why should I join Girls Who Code?',
        'Why is Girls Who Code teaching Python rather than Java?',
        'Will Girls Who Code offer support for AP CS A and CS P students?',
        'Can non-binary people join GWC?',
        'When is the first meeting?',
        "What time and location is the Girls Who Code meeting?",
        "On which day does Girls Who Code meet?",
        "At what time does Girls Who Code start?",
        "Where does GWC meet?",
        "What time do Girls Who Code meetings conclude?",
        "What is the duration of each Girls Who Code meeting?",
        "Who advises the Redmond High School Girls Who Code club?",
        "Why was Girls Who Code created?",
        "Who is eligible to join Girls Who Code?",
        "What steps do I need to take to join the Girls Who Code club?",
        "Is there a fee to join Girls Who Code?",
        "What activities are planned by Girls Who Code?",
        "Is previous coding experience required to join Girls Who Code?",
        "What is the frequency of Girls Who Code meetings?",
        "What will I learn by participating in Girls Who Code?",
        "Does Girls Who Code offer internship or scholarship opportunities?",
        "Is the club useful for college applications?",
        "What are the criteria for running for the Girls Who Code board?",
        "How do I reach out to the leadership team of Girls Who Code?",
        "How was Girls Who Code founded?",
        "Is Girls Who Code collaborating with any other clubs?",
        "Is there anything required before joining Girls Who Code?",
        "Which programming languages will be taught in Girls Who Code?",
        "Does Girls Who Code provide any certifications or awards?",
        "Can I work on real-world projects in Girls Who Code?",
        "What should I do if I miss a Girls Who Code meeting?",
        "Which hackathons does Girls Who Code join?",
        "Is it possible to suggest new events or workshops for Girls Who Code?",
        "Where can I find Girls Who Code on social media?",
        "What do the board members of Girls Who Code do?",
        "Is there a way to give feedback to Girls Who Code?",
        "What future plans does Girls Who Code have?",
        "What sets Girls Who Code apart from other CS clubs?",
        "Is Girls Who Code open to boys?",
        "What are the benefits of joining Girls Who Code for girls?",
        "What is the current membership count of Girls Who Code?",
        "What is the process for electing board members in Girls Who Code?",
        "Which grades are the board members of Girls Who Code in?",
        "What equipment is necessary for Girls Who Code members?",
        "How will Girls Who Code communicate with its members?",
        "Why is it important for girls to study computer science?",
        "Which areas of computer science will be explored in Girls Who Code?",
        "Is Girls Who Code an enjoyable experience?",
        "Can you explain what Girls Who Code is?",
        "What makes Girls Who Code worth joining?",
        "Why does Girls Who Code focus on Python instead of Java?",
        "Does Girls Who Code provide help for AP CS A and CS P students?",
        "Is Girls Who Code inclusive of non-binary individuals?",
        "What date is the first Girls Who Code meeting?",
        "How is GWC different from the other computer science clubs at the school?",
        "What does GWC offer that other computer science clubs don't?",
        "Why does Girls Who Code club meet?",
        "On what day is the first GWC meeting?",
        "What internship opportunities will Girls Who Code provide?",
        "Which competitions will GWC be part of?",
        "What hackathons are GWC participating in?",
        "When does GWC start?",
        "When do meetings for GWC start?",
        "What will we be doing in Girls Who Code?",
        "Why should I join GWC?",
        "Can boys join?",
        "Is this curriculum provided in school?",
        "What is the age range?",
        "Do I need a laptop?",
        "How much does it cost?",
        "What kind of experience needed?",
        "Do you go on field trips?",
        "What kind of coding?",
        "Why is this good for me?",
        "What do you learn at Girls Who Code?",
        "Will Girls Who Code help me with my college application?"
    ],
    'Bot Response': [
        'We meet on Tuesday mornings in D103.',
        'Girls Who Code meets on Tuesday.',
        'Girls Who Code meets from 7:30 AM to 8:20 AM.',
        'GWC meets in room D103.',
        'Girls Who Code meetings end at 8:20 AM when school starts.',
        'GWC meetings are about 50 minutes long.',
        'Our advisor is Ms. Weber, the AP CS P teacher.',
        'The gender gap in computing is huge, leading girls who are interested in computer science to give up due to alienation. Girls Who Code aims to support and increase the number of women in computer science by not only teaching skills but also fostering sisterhood among its members.',
        'Anyone can join, from girls to boys to people who are non-binary! We encourage boys to attend meetings once or twice to understand what minorities in the industry experience, but not on a daily basis as we do not want girls being marginalized again.',
        'You can join the club by signing up on the forms across the school or emailing one of our board members: 1041602@lwsd.org (president), 1042602@lwsd.org (vice president), 1060660@lwsd.org (secretary), 1060794@lwsd.org (public relations officer).',
        'Joining the club is completely free.',
        'We\'re going to make a chatbot just like this one in the near future! We might have guest speakers and join hackathons, but that is pending.',
        'No, Girls Who Code welcomes all skill levels, from beginners to experienced coders.',
        'GWC meets weekly.',
        'You will learn how to protect yourself online, code in Python, make AI, create websites, and much more.',
        'We can introduce you to some opportunities, but it is up to you to apply and work the job.',
        'If you complete all the projects from this club, it can add up to an impressive portfolio! Portfolios show dedication to the major you are applying to, so GWC can definitely help with college applications.',
        'You can run for the board if you attend half the meetings every month.',
        'To contact the club\'s leadership, email each of us or send us a Teams chat. Here is the president\'s email: 1041602@lwsd.org.',
        'Girls Who Code was founded by Reshma Saujani in 2012, who came up with the idea of creating the organization during her run for the United States Congress. Reshma\'s inspiration stemmed from finding that schools along her campaign route lacked female representation in computer science classrooms.',
        'We are planning a collaboration with the Design Club on UI/UX design.',
        'You just need to be currently enrolled in Redmond High School.',
        'We will be teaching Python at the beginning of the year, but we may also dabble in JavaScript, CSS, HTML, and C#.',
        'No, but if you join the summer program, you can earn intermediate or beginner-level certificates in Web Development, Cybersecurity, and Data Science + AI.',
        'Absolutely. After each lesson, we will complete a project, including a website portfolio and a chatbot like this one.',
        'All materials will be posted in Teams.',
        'There are no mandatory hackathons for this club, but you can use the club to form teams to participate in the hackathons we inform you of.',
        'Absolutely. Just email the president and co-president describing your idea.',
        'On Instagram, follow us at @redmondgwc.',
        'The President and VP are responsible for leading lessons and planning events. The Secretary is responsible for keeping track of attendance and taking meeting minutes. The PR promotes the club and keeps the club updated on events and changes.',
        'There will be one given during the first meeting. Be on the lookout for more throughout the year!',
        'The club will complete more projects and cover more topics compared to last year.',
        'Girls Who Code has a Women in STEM presentation every month, which helps young girls feel less alienated and more inspired in a male-dominated field.',
        'Despite the club\'s name, anyone can join.',
        'Many girls interested in computer science feel alienated in the male-dominated computer science clubs of this school. Girls Who Code is a club where girls can form genuine connections and feel safe while coding. Furthermore, many girls are enrolled in AP CS A/P. The board members of this club can offer support on AP CS A/P by sharing practice resources and explaining concepts, especially CS A because it is a difficult class.',
        'Girls Who Code currently about 80 members on Teams.',
        'Board members are elected by popular vote.',
        'Two board members are juniors, while the other two are sophomores.',
        'All equipment will be provided by the school. We are a computer science club, so we will use the PCs in Ms. Weber\'s room.',
        'Members will be notified of events and meetings through Teams, Outlook, and Instagram.',
        'Girls should join computer science because the world is moving online, and girls should not be left behind!',
        'GWC will cover video game design, web development, and artificial intelligence as of now. Feel free to leave suggestions for any fields you want us to explore!',
        'We are trying to make Girls Who Code fun by incorporating games and cool programs you can play around with, but "fun" is dependent on your passion for computer science.',
        'Girls Who Code (GWC) is a global nonprofit organization dedicated to closing the gender gap in technology by empowering young women through coding education and community support. It offers after-school clubs, summer programs, and college-level initiatives that teach programming skills, web development, and other tech competencies. By fostering a supportive and inclusive environment, GWC aims to build confidence in girls and increase their participation in computer science, thereby addressing the gender imbalance in the tech industry and inspiring future female leaders.',
        'In Girls Who Code, you will complete many projects that can be useful for college applications. Furthermore, the sisterhood in GWC will help you get a taste of belonging in a male-dominated field, allowing you to learn teamwork skills and strengthen your passion with other girls.',
        'Python is easier to learn as a beginner and ties in nicely with the artificial intelligence and web development units later in the year. It is also a waste of time for AP CS A students to be relearning Java in GWC.',
        'Our secretary Emily and our PR officer Stephanie have both taken AP CS P, so if you need help, feel free to reach out to them. The vice president Amruta and president Grace have both taken AP CS A. We will offer study sessions, test-taking strategies, and study materials for both AP CS A and CS P a month before the AP tests.',
        'The GWC website states, \'Girls Who Code is a nonprofit organization that offers coding programs, clubs, and events for girls and nonbinary students of all ages.\' So yes, non-binary people can absolutely join Girls Who Code.',
        'The first meeting takes place on the first of October.',
        'Girls Who Code meets in room D103 every Tuesday before school.',
        'Girls Who Code gathers every Tuesday.',
        'Our meeting time is from 7:30 AM to 8:20 AM.',
        'The meetings are conducted in room D103.',
        'Meetings conclude at 8:20 AM when school begins.',
        'Each Girls Who Code meeting lasts about 50 minutes.',
        'Ms. Weber, who teaches AP CS P, is our advisor.',
        'The gender gap in computing is large, often causing girls interested in computer science to feel isolated and discouraged. Girls Who Code aims to bridge this gap by not only teaching technical skills but also building a supportive community among its members.',
        'Girls, boys, and non-binary individuals are all welcome to join! However, the club primarily focuses on supporting girls, as they are underrepresented in the field of computer science.',
        'You can join by signing up through the forms available around the school or by emailing one of our board members. The emails are as follows: 1041602@lwsd.org (president), 1042602@lwsd.org (vice president), 1060660@lwsd.org (secretary), 1060794@lwsd.org (public relations officer).',
        'Membership in Girls Who Code is completely free of charge.',
        'We plan to create a chatbot similar to this one soon! There may also be guest speakers and participation in hackathons, though details are still being finalized.',
        'No prior coding experience is necessary; we welcome members of all skill levels.',
        'Girls Who Code meets once a week.',
        'You will learn online safety, Python programming, AI development, web design, and much more.',
        'We can connect you with opportunities, but it’s up to you to apply and secure the position.',
        'Completing all the club projects can build a strong portfolio, showcasing your dedication to your major and assisting with college applications.',
        'You’re eligible to run for the board if you attend at least half of the meetings each month.',
        'To get in touch with the club’s leadership, you can email us or send a message via Teams. The president’s email is 1041602@lwsd.org.',
        'Girls Who Code was founded in 2012 by Reshma Saujani, who was inspired to create the organization during her campaign for the United States Congress after noticing a lack of female representation in computer science classrooms.',
        'We’re collaborating with the Design Club on a UI/UX design project.',
        'You only need to be a current student at Redmond High School to join.',
        'We’ll start the year by teaching Python, but we might also explore JavaScript, CSS, HTML, and C#.',
        'No certifications are offered directly through the club, but participating in the summer program can earn you certificates in Web Development, Cybersecurity, and Data Science + AI at beginner or intermediate levels.',
        'Definitely. After each skill taught, we’ll work on a project, including a website portfolio and a chatbot like this one.',
        'All meeting materials will be shared on Teams.',
        'Hackathon participation is optional, but the club can help form teams for those interested in events we announce.',
        'Yes, you can propose new events or workshops by emailing the president and co-president with your ideas.',
        'Follow us on Instagram at @redmondgwc.',
        'The President and VP lead lessons and organize events, the Secretary tracks attendance and records meeting minutes, and the PR officer promotes the club and keeps everyone informed about events and updates.',
        'We’ll provide one at the first meeting, with more to come throughout the year.',
        'This year, the club will complete more projects and explore additional topics compared to last year.',
        'Each month, Girls Who Code hosts a Women in STEM presentation to inspire young girls and reduce feelings of isolation in a male-dominated field. This presentation is unique to GWC.',
        'Despite the name, Girls Who Code is open to everyone.',
        'Many girls interested in computer science feel out of place in the male-dominated computer science clubs at this school. Girls Who Code provides a safe space where girls can connect with each other and feel comfortable while learning to code.',
        'Girls Who Code currently has over 70 members on Teams.',
        'Board members are elected through a popular vote.',
        'Two of the board members are juniors, and the other two are sophomores.Girls Who Code teaches',
        'All necessary equipment will be provided by the school. Since we are a computer science club, we’ll be using the PCs in Ms. Weber’s room.',
        'We’ll notify members about events and meetings through Teams, Outlook, and Instagram.',
        'Girls should consider computer science because the future is increasingly digital. Girls should customize this future to cater to themselves, not only men alone.',
        'This year, Girls Who Code will focus on video game design, web development, and artificial intelligence. We welcome suggestions for additional areas to explore!',
        'We’re making Girls Who Code fun by incorporating games and interactive programs, but what\'s fun depends on your interest in computer science.',
        'Girls Who Code (GWC) is a global nonprofit organization dedicated to reducing the gender gap in technology by empowering young women through coding education and community support. It offers after-school clubs, summer programs, and college-level initiatives that teach programming skills, web development, and other tech competencies. By fostering a supportive and inclusive environment, GWC aims to build confidence in girls and increase their participation in computer science, thereby addressing the gender imbalance in the tech industry and inspiring future female leaders.',
        'In Girls Who Code, you\'ll complete numerous projects that can strengthen your college applications. Additionally, the sisterhood within GWC will give you a sense of belonging in a male-dominated field, helping you develop teamwork skills and grow your passion for computer science alongside other girls.',
        'Python is a great language for beginners and ties in well with the AI and web development topics we’ll cover later in the year. For AP CS A students, re-learning Java in Girls Who Code would be redundant.',
        'Our secretary, Emily, and PR officer, Stephanie, have both taken AP CS P, so feel free to reach out to them if you need help. The vice president, Amruta, and president, Grace, have both taken AP CS A. We’ll hold study sessions, share test-taking strategies, and provide study materials for both AP CS A and AP CS P a month before the AP exams.',
        'The Girls Who Code website states, \"Girls Who Code is a nonprofit organization that offers coding programs, clubs, and events for girls and nonbinary students of all ages.\" So yes, non-binary students are absolutely welcome to join.',
        'The first meeting will be held after the Club Jamboree on October 1.',
        'Girls Who Code is the only CS club that aims to empower women. It is the only club with a sisterhood & where girls can feel like they belong.',
        'Girls Who Code presents on Women in STEM in hopes of inspiring young girls to follow in the footsteps of these pioneering engineers. This is unique to GWC.',
        "Girls Who Code meets to empower and inspire girls to pursue careers in technology, providing them with the skills and support needed to excel in computer science. The meetings typically focus on coding, problem-solving, and collaboration while building a strong community of like-minded individuals who share a passion for tech. This school year, this includes learning Python, AI, cybersecurity, and more.",
        "The first meeting takes place on the first of October.",
        "Girls Who Code doesn't offer internship opportunities, but we will introduce opportunities to members.",
        "Girls Who Code will host its own hackathon at the end of the school year. GWC will not formally participate in competitions, but we will introduce competitions to our members so they can sign up on their own.",
        "Girls Who Code will host a hackathon in March. All club members and girls and non-binary people from outside the club are free to compete.",
        "GWC meetings start anywhere from 7:30 AM to 7:45 AM.",
        "Meetings for Girls Who Code have varying start times from 7:30 AM to 7:45 AM.",
        "Girls will learn Python at the beginning of the year, then they will learn the principles of web development (HTML, CSS, JavaScript) and code their own website. Next, girls will learn concepts in AI including supervised and reinforcement learning and code their own models. Other topics include cybersecurity and AP CS A/P review. During the second semester, girls will also have the chance to participate in the GWC Hackathon, a local hackathon that is great for gaining experience.",
        "You should join GWC because you will learn coding skills & teamwork skills, as well as make lifelong friendships with people who share your interests. You should also join because the projects we make will help develop your portfolio for college.",
        "Girls Who Code designed a program specifically targeted toward girls in order to provide them with guidance, knowledge, and encouragement in computer science. They hope to bridge the gender gap between the 18% of computer science graduates who are women and the other 82% who are men.",
        "What we teach is unique to our club; Girls Who Code is an independent organization represented through numerous clubs throughout the United States.",
        "Any girl or nonbinary person from 9th grade to 12th grade can join.",
        "Laptops are recommended, but D103 also has desktop computers you can use.",
        "Girls Who Code is free to join.",
        "You can come as a blank slate; we will teach you the basics of programming!",
        "No, we do not go on field trips.",
        "We will learn HTML, CSS, Javascript, and Python.",
        "This program encourages and guides girls with interests in computer science. They will be the beginning of a generation of girls who code!",
        "At GWC, members will learn programming languages, project management, problem solving, and various computer science concepts.",
        "Being involved in a club is considered an extracirricular, which is considered by colleges during applications. Furthermore, Girls Who Code will guide members through projects, helpful for developing a portfolio for colleges to gauge your dedication."
    ]
}
df = pd.DataFrame(data)

# %%
df.head()

# %%
row_count_per_column = df.count()

print(row_count_per_column)
# Out:
# User Input      120
# Bot Response    120
# dtype: int64

# %%
file_path = '/content/drive/My Drive/gwc_chatbot_data_revised.csv'

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)
